# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !mkdir input_data
# !unzip "/content/gdrive/My Drive/Bases_VisagioHackathon.zip" -d "/content/input_data"
# Out:
# Mounted at /content/gdrive
# Archive:  /content/gdrive/My Drive/Bases_VisagioHackathon.zip
#   inflating: /content/input_data/Base_tweets_saúde_Aos_Fatos.xlsx
#    creating: /content/input_data/FakeHealthData/
#   inflating: /content/input_data/FakeHealthData/Base News Releases.csv
#   inflating: /content/input_data/FakeHealthData/Base Story.csv
#   inflating: /content/input_data/FakeHealthData/de_para_news_questions.csv
#   inflating: /content/input_data/FakeHealthData/de_para_story_questions.csv
#   inflating: /content/input_data/FakeHealthData/news_tweets.csv
#   inflating: /content/input_data/FakeHealthData/story_tweets.csv

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !git pull
# !pip install --upgrade .
# !pip install sentencepiece
# !pip install transformers
import torch
import sentencepiece
import gc
gc.collect()
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 54705 (delta 19), reused 22 (delta 8), pack-reused 54657
# Receiving objects: 100% (54705/54705), 40.84 MiB | 17.48 MiB/s, done.
# Resolving deltas: 100% (38239/38239), done.
# /content/transformers
# Processing /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (1.18.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (20.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (2019.12.20)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (0.8)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 12.8MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 54.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==4.1.0.dev0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==4.1.0.dev0) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.0.dev0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.0.dev0) (0.17.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.1.0.dev0-cp36-none-any.whl size=1375102 sha256=6a29573dd47605843bd512a3d40f16046776ad310e7816ee2ed72ffa04764a87
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hfpwixah/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# Successfully built transformers
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=f6ad39d145ad286b4cd81cdf59d8d172161fed2f79f5a15c04f781491185409f
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.1.0.dev0
# Already up to date.
# Processing /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied, skipping upgrade: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (0.0.43)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (2.23.0)
# Requirement already satisfied, skipping upgrade: tokenizers==0.9.4 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (0.9.4)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (2019.12.20)
# Requirement already satisfied, skipping upgrade: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (0.8)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (3.0.12)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (1.18.5)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (4.41.1)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.0.dev0) (20.4)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.0.dev0) (0.17.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.0.dev0) (1.15.0)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.0.dev0) (7.1.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (2020.11.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.0.dev0) (1.24.3)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==4.1.0.dev0) (2.4.7)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.1.0.dev0-cp36-none-any.whl size=1375102 sha256=7f96dc0d9d7d3f91748ad6d043168f5574223372b7da4d3195fde20ddf138531
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kzjixh7y/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# Successfully built transformers
# Installing collected packages: transformers
#   Found existing installation: transformers 4.1.0.dev0
#     Uninstalling transformers-4.1.0.dev0:
#       Successfully uninstalled transformers-4.1.0.dev0
# Successfully installed transformers-4.1.0.dev0
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/e5/2d/6d4ca4bef9a67070fa1cac508606328329152b1df10bdf31fb6e4e727894/sentencepiece-0.1.94-cp36-cp36m-manylinux2014_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 13.6MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.94
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (4.1.0.dev0)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.9.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# 20

# %%
import pandas as pd
base_news_releases = pd.read_csv('/content/input_data/FakeHealthData/Base News Releases.csv',encoding='utf-8',sep=';')
base_news_releases.head(2)
# Out:
#    Unnamed: 0  ...                             question_9_explanation
# 0           0  ...  The release says this device could be an impro...
# 1           1  ...  The lead researcher calls the study “an exciti...
#
# [2 rows x 49 columns]

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
import torch

# %%
base_news_releases['text'] = base_news_releases['text'].astype(str)

# %%
def summary_generate(text,model,tokenizer):
  '''
    Generates the summary of a text based on a given model.
  '''

  if len(text.split())>4200:
    max_length_in = 600
    min_length_in = 300
  
  elif ((len(text.split())<4200) and (len(text.split())>3000)):
    max_length_in = 500
    min_length_in = 200

  else:
    max_length_in = 200
    min_length_in = 80
  
  batch        = tokenizer.prepare_seq2seq_batch([text], truncation=True, padding='longest', return_tensors="pt").to(torch_device)
  translated   = model.generate(
                                **batch,
                                max_length = 500, # max length of summary
                                min_length = 200, # min length of summary
                                do_sample = True, 
                                temperature = 3.0,
                                top_k =30,
                                top_p=0.70,
                                repetition_penalty = 1.2,
                                length_penalty = 5, # if more than 1 encourage model to generate #larger sequences
                                num_return_sequences=1) # no of summary you want to generate)
  tgt_text     = tokenizer.batch_decode(translated, skip_special_tokens=True)
  return tgt_text[0]

# %%
model_name   = 'google/pegasus-newsroom'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer    = PegasusTokenizer.from_pretrained(model_name)
model        = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1912529.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=65.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=87.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1119.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=2275329241.0, style=ProgressStyle(descr…

# %%
summary_result = []
for i in range(base_news_releases.shape[0]):
  
  text = base_news_releases.loc[i,'text']
  summary = summary_generate(text,model,tokenizer)
  summary_result.append(summary)
  print('Summary Generated:-{}'.format(summary))
  print('\n')
# Out:
# Summary Generated:-A new device could provide a new weapon to help fight obesity and its many health-related problems -- without the headaches of bulky batteries and electrical currents or the ongoing maintenance that is typically involved with existing drugs and surgical devices to stimulate a particular nerve or part of the brain to regulate how much we can handle. The device, which can be implantable using a minimally- invasive procedure, is small enough for rats to carry around and generated gentle electricity when the rats' stomach moved. When removed, the devices restored rats' appetites, and they gained back less than a pound a week after returning to the same proportions they had prior to removing the devices. It also offers a more flexible approach than existing systems that involve external batteries, complex wiring and long-term maintenance requirements. "That's another reason these systems are being tested in humans now, so we can get them into a human clinical setting where they can have the same results as those in the animals," says Wang, a materials scientist who has spent the past decade developing devices for the medical and dental fields.
#
#
# Summary Generated:-A new study shows that in a combination of chemotherapy and gene editing, tumors grow smaller and volume is decreased in a mouse that has been treated with lung cancer. The research could provide a new approach to treating lung cancer and may also lead to future applications of gene editing in other diseases such as diabetes, according to scientists at Christiana Care Health System in Wilmington, who are collaborating on the study. The gene-editing method, called CRISPR-Cas 9, targets a specific type of gene that is critical for cancer survival, but the study finds that in addition to preventing tumors from growing, CRISPR-Cas9, also disables another important gene in the body that helps these cancers resist the chemotherapy agent iris or docetaxel, helping them to grow faster, survive longer and prevent them from returning. The findings, published in the Journal of Medical Oncology, were supported by the Whitehead Cancer Center and Christiana Medical Research Foundation, along with several foundations that have committed to supporting the work of the gene- Editing Institute and Christiana Care Health System.
#
#
# Summary Generated:-About three years ago there were few treatments that could reverse the course of depression. That changed after the emergence of mood-enhancing drugs and the rise of prescription antidepressants, but today there are some surprising approaches that might be able to treat mood disorders and other psychiatric problems. Some are using probiotics, which have been associated with better health in mice, as an alternative to psychotherapy, antidepressants or other medications. In a study published in Nature, researchers from Sheppard Pratt report that adding a fermented probiotic supplement was linked to significant improvement in mood among bipolar patients. The results may be good news for people who have bipolar disorder, or anyone living with psychiatric disorders, because these treatments can have many of the same positive benefits, but they require a long-lasting commitment from patients and their doctors, and the results of this research could open up many new medical avenues, including treatments that use probiotic microbes to fight off the onset of disease. Here are a few more promising ideas that might be worth considering if your doctor wants to consider treating your psychiatric disorder, especially if your condition is linked to an gastrointestinal tract disorder like bipolar disorder.
#
#
# Summary Generated:-Thousands of people will get better health outcomes if they supplemented with dairy to the MedDiet. A recent study shows this would be even better than the current low- Fat Diet. The University of South Australia says it is an ideal option for those seeking to improve their health, but many people are not familiar with the benefits of dairy, especially because it is more in fat than the traditional MedDiet and is perceived as healthier than its low fat counterparts, which is also known for their benefits to cardiovascular health. This is a major finding because we know that diets rich in fats can actually be bad for the body and contribute to the accumulation of fat in our arteries, contributing to the onset of heart disease, which leads to death. In contrast to the healthy fats, milk contains a large dose of calcium which helps fight osteoporosis and prevents fractures. It is also found to have a low incidence of heart disease, hypertension and stroke, which help keep us healthy. It can also help keep the blood pressure stable and reduce cholesterol levels. The study also shows that a dairy- enhanced Mediterranean diet was much superior to a low- Fat Diet for improving health, especially in terms of improving the heart health and cognitive function.
#
#
# Summary Generated:-Two studies published in December will identify three potential radiopharmaceuticals that may help to speed the discovery and diagnosis of diseases, such as Alzheimer's disease, which has no definitive diagnostic test but remains difficult to diagnose in actual humans. The team is working to make Tau PETs more available and use them more frequently in clinical studies, in part because they have the potential to improve imaging quality by watching tau tangles in the brain more quickly and at a higher resolution than standard brain PET scans do, and could provide a more efficient way to test for Alzheimer's in the clinic and in trials to develop drugs that target those proteins in an effective way. The findings were published online by the Journal of Nuclear Medicine, in a study published as the cover story of a special issue on "Radioactive Tau Molecules: Potential for characterization of tau tangles and development of new treatments." The paper, "Tau PET molecular profiling: Three promising radiopharmaceutical compounds in Alzheimer's treatment and prevention" is co-authored by Dean Wong of Johns Hopkins University, Robert S. Price of the University of California, San Diego, and other Johns Hopkins researchers.
#
#
# Summary Generated:-A new minimally-invasive surgical technique helps to prevent the life-threatening condition from coming back up and spreads faster, allowing people with aneurysms to return to everyday activities without having their lives interrupted by a risky operation that is often required. The procedure, called a carotid stent graft, has already been successfully performed on several patients in Cedars-Sinai’s Vascular Surgery department and Azizzadeh, a leading authority in the use of new technologies, has served as principal investigator on the study that showed this device could be safely used for treating aneurysms in patients with very old or otherwise weak arteries that connect the body’s major veins to its coronary arteries, making surgery easier and safer for both parties. “I am thrilled to have been able to successfully perform this new procedure for these patients and I am proud to be one of the first doctors to use the new stent graft, which is the only device on the market to help treat an aneurysm at this point, without the invasive procedure that has been traditionally associated with this particular condition,” Azizzadeh said.
#
#
# Summary Generated:-Newswise <n> vitamin c may reduce harm to airways of unborn babies born to smoke moms <n> <n>According to a study, Vitamin C could reduce harm to lungs by improving infant airway function before the child is born, a finding that could help protect these babies from exposure to cigarettes before they are born and potentially prevent smoking-related illness in later years. The results of this trial, which studied the effects of vitamin C on the health of infants born to pregnant women with a high incidence of tobacco use, are published online in the  journal  Annals of Pediatric Research  where they are featured as  New York Times  Best Research in Medicine  <n> <n>This is the most recent study to confirm the benefits of vitamin C to protect babies from lung damage after their birth, and researchers are hopeful that their findings will help others who are at risk of developing asthma or obstructive lung disease when they grow up and give them an early education and support to overcome their nicotine addiction and avoid the lifelong health risks of tobacco use that are linked to asthma, lung disease and cancer in later life.
#
#
# Summary Generated:-Apixaban may help cancer patients without the bleeding and death associated with current treatments; new oral drug has numerous benefits, but there are some significant drawbacks, says researcher, Mayo cardiologist Robert McBane, II, M.D., M.D. About apixaban The medication is an oral pill that is usually given in a tablet or nasal form. With the new clinical trial, patients taking this oral drug had higher rates of bleeding than those who took low-molecular-weight heparin -- and fewer clots were seen when patients used this drug over the conventional blood- thinners. The results are from an international, large study of nearly 4,000 cancer patients that is published in the online version of The American Medical Assn. s  journal, ClinicalTrials.gov (http://www.clinicaltrials.gov/mct/etv/trial_abstract.asp?s=apixaban).  It is also available as an injectable pill. The study involved patients with prostate cancer undergoing treatment for tumors in the bladder, breast, lung, ovary, venoid sclerotitis, melanoma, pancreatic <n> Hodgkin <n>'s disease, leukemia, lymphoma and brain tumors. It is performed at Mayo Clinic Cancer Center in Arizona and will be available to customers in the U.S. starting in 2011. <n> <n> For more information about how it works, or for questions about other drugs available, contact Mayo Clinic Cancer Center at 1-800-257-8867, Monday-Friday 11 a 7:30 a.
#
#
# Summary Generated:-A new study by University of Seville scientists suggests the traditional medicine of a tree in the AMAZON region can help sufferers of this autoimmune disorder, with the same positive effects on the brain and nervous system seen with diabetes. The results are expected to be presented next year in a scientific journal, which may have a huge influence on how we diagnose, treat, and prevent this disease that has an estimated impact on up to half of all people living in Spain, but has little awareness of its cause or cures. The research was carried out on rats used in a study on the symptoms of fibromyalgia, in which researchers used a standard diet supplement to see if it could help the condition in patients, but it seems as though there is a greater benefit for them to take aqueous extract from the leaves of this species, which is a plant native to the tropics of the Americas and can be cultivated in the AMAZON area, where this tree is endemic, and in which it has a long history and a well known medicinal role for pain reduction, infection prevention and immune system enhancement. The consumption of this traditional drug could be a step towards treating this chronic, debilitating disorder, as well as a way of reducing the severity of its symptoms.
#
#
# Summary Generated:-Pulsed radiofrequency treatment creates a modulation of pain signals, helping to improve the quality of life and speed recovery for people with lumbar disk-hindering or sciatica pain, researchers report at RSNA. The treatment was more effective in reducing pain and reducing disability scores than steroid injection only, and also provided better results. The one-year outcome results showed pRF's superior to injections as a means of treating sciatica in patients with lumbar disk herniation who had no response to conventional treatments, researchers report atRSNA, which is hosting the research on June 9 - 11 at Chicago's McCormick Center. The study is part of a three-year study that shows pRF can provide more immediate relief and may help patients who have had conservative treatment, such as injections, get better results without surgery, say investigators. The findings appear in Annals of Internal Medicine, scheduled for publication June 14  - July 2 ; Dr. Napoli and colleagues found that one year after the first session, patients who received pRF had improved overall symptom control and had faster recoveries from the pain than patients given injection only treatment.
#
#
# Summary Generated:-Newswise – Boston, Mass – physicians have used electrode devices to stimulate nerves in the smell bulb, and they are showing that it's possible to do that for some who have lost a sense of smell, a finding that has potential for future development of implant technology to give people a way back into the sense of odor, as is now done for people who lose a sense of speech or touch, which is also an area where we might like to pursue new developments. The study was described today on the sidelines of the 66th annual International Allergy &Rhinology congress in New Orleans. The work, led by researchers from the University of Massachusetts-Lowell, could help those who have lost the ability to smell by stimulating nerves in their noses with electrodes, a process that can be performed using other devices, including a cochlear implant. “The idea behind this is that we would have an implant that sends the odor back into the nose, where it would reach its original sensory receptors and allow people to regain the smell that is lost when a damaged or injured part of the olfactory system becomes damaged or damaged, and that may be a good thing because there is a huge market for this type of device, which is not yet available to the general public, especially since it has such limited functionality, so it might have advantages over other devices, including those already in use, such as cochlear implants. We're making progress, but it still seems like a long way to way to go. In the next five years, cochlear implants will likely be only a lot more common, so we still won’t have lots of...
#
#
# Summary Generated:-A single MRI brain scan could be a powerful test that tells doctors how early a patient might suffer from memory loss or other dementia, researchers say. The finding may help doctors monitor older patients before they suffer the disease, which is incurable but can be treated early with drugs or by undergoing treatment at a hospital. The study appeared Sunday, Nov. 25, on the cover of Annals of Neurology, a publication of The American Society For Radiology. It's the first time MRI-based biomarkers have been studied as a preventive tool against dementia and could have wide applications in Alzheimer's treatment, according to researchers. They say that MRI scans may someday help identify patients with dementia before they develop memory impairment, which could help doctors better assess and manage patients' symptoms and provide early detection of the disease, which can be diagnosed with traditional screening tests including PET scans, cognitive exams, and even tests for a genetic risk of Alzheimer's. "Our study shows that MRI Brain Scans Are Predictable to Determine Dementia Risk 2.6 Years Before Dementia Is detectable, and could help predict dementia years in advance, which would allow for more timely diagnosis of dementia and earlier treatment, and better treatment, in some patients, especially those with dementia," said Cyrus Raji, lead author of the report. "Our findings suggest that using MRI scans could eventually help doctors detect dementia decades early, allowing them to take appropriate action before symptoms strike."
#
#
# Summary Generated:-New blood test has potential to help clinicians detect ovarian cancer at its earliest stage. The test, engineered with a harmless component from a toxin, can identify the abnormal sugar glycan expressed on ovarian cancer cells and could potentially provide early diagnosis and treatment of this lethal disease, says researchers. The test may also be suitable for testing in healthy controls and could be used as a screening tool for women with other cancers, such as breast, lung, and brain tumors, says the team, with the potential for use in all cancers except for melanoma, which has been found more often in people with genetic mutations than in others, including cancer of the ovaries. The test will be further investigated by scientists and clinicians to understand how to make and use it, but the new technology is very much in the early development stages and there are still a number of hurdles before it is commercially available, says Professor Michael Jennings from Griffith's Institute of Biophysical Research. He explains:"It has the potential to significantly improve early detection of this disease and it could also be utilized for a host of other cancers, such as breast, colon, lung and other types of tumors." strong>The University of Adelaide and Griffith University research team has created a harmless part of an enzyme that has been found in some bacteria, making it a good candidate to enhance sensitivity and specificity for ovarian cancer glycan./strong>
#
#
# Summary Generated:-Rockville, Md. (October 16, 2018-- NIH scientists say hot water bath baths may increase the production of cytokines, a type of chemical found in cells, which may be an alternative to exercise and lower inflammation in sedentary, obese people. Researchers have shown that high-heat baths may reduce inflammation and insulin levels at rest, but they're unclear how much benefit hot water immersion will have in improving blood sugar levels in obese people, or what happens after the immersion session. The results may help explain why hot water baths have become increasingly popular among bodybuilders, fitness enthusiasts and others who want to feel great, stay slim and feel great, but are reluctant to take part in exercise due to the possibility of uncomfortable and uncomfortable experiences, the researchers said. But the study doesn't yet prove hot water baths help with diabetes, because the men's fasting blood sugar did not change after hot water immersion, but their insulin sensitivity was better than during a control trial. The results also suggest hot water immersion can improve inflammatory and blood sugar levels in overweight men. However, these findings are still in early clinical trial stages, and there is no way to know for sure whether hot-water immersion will help improveInflammation, BloodSugar & insulin sensitivity in sedentary, overweight men; Study published ahead of print in Journal of Applied Physiology
#
#
# Summary Generated:-The first trials of its kind have started in the world in the first ever attempt to safely and efficiently treat a disease with very high priority for both patients and medical experts. This treatment may have the potential to change the standard of care for prostate cancer and may even help some patients escape the negative effects that such procedures often bring to men with prostate cancer, especially in men with high-risk profiles, including those with prostate cancer diagnosed within the last decade who are on Provenza and other traditional treatments, or are already on radiation and radiation therapy, which are both more complicated and time consuming and may be harmful, but which have never before been tested using these nanoparticles. This new treatment is being conducted in Houston, which has an excellent track record in prostate research and is a great place to find the latest in medicine and science, which means it's well-positioned to offer this treatment to patients around the country, especially in communities that are less urban and have a much more diverse population, which can make diagnosis of cancer harder for experts and doctors to identify, but could mean better treatment options for those who live in urban centers and have a high risk of disease.
#
#
# Summary Generated:-Transplanted gut bacteria can treat colitis, finding a first-line treatment that could extend the survival times and improve health of colitis patients who suffer from Immune Checkpoint Immunizaton inhibitors (ICIs), which are known to increase the incidence of severe colitis in those receiving these immunotherapy treatments. The study, which included two patients, is being published in Nature Medicine, and researchers say it could be evaluated in further trials to treat the common side effects from immunotherapy, such as increased sensitivity to antibodies, which is seen when patients continue ICIs after a certain amount of time, or to stop them for longer periods, when they are unable to fully restore their body’s own natural defense system against the antibody-blocking drugs, which have been associated with toxicities, including infection. “These findings are exciting because we think that this is a safe, quick therapy, that can last long time, that can help people, who are very sick, even with chronic conditions, to have a healthierColon, which is why we used this technique in the first place to treat this particular type of colitis, which has such a high rate of relapse,” explained senior researcher Yinghong Wang. “This study suggests that fecal microbiota transplants are worth exploring in clinical trials as a therapy for this common side effect of immunotherapy, which could be a game-changer in treating people with severe colitis. These results are exciting, but now we need to do more clinical trials, and to make sure that it is safe for people.”
#
#
# Summary Generated:-UNC researchers are looking to use at-home HPV tests to screen women overdue for testing, showing how self-collection at home might help detect early cervical cancer, an disease that has been associated with high rates of mortality for many women in North Carolina, where mailing these kits could be a way to reduce the time women delay getting screened, particularly for women who are low income, elderly, white and have a previous health history or who have no close relatives who suffer from cervical cancer, such as their husbands or fathers. The study found that women were found to have high-grade precancerous growths in all of those tested; more testing could improve screening access and lower costs, the researchers say, because it's possible to return the test kit to find HPV after it has gone away, which could reduce its risk of recurrence by more than 99 percent. Cervical cancer is the number one cancer-related disease that kills US women aged 10 to 65, and most cancers occur in older women, the study found. Cervical cancer is also a leading reason women don't get recommended Pap tests for cancer. More than 3,000 women die from the disease in the United States annually. Women can receive HPV screening for free or for a small fee at some health care facilities, but it is often hard for women to take the time for a trip to a clinic, so women need to be screened sooner, too.
#
#
# Summary Generated:-A study has found a direct correlation between fermented dairy products and the risk of incident coronary heart disease. The findings suggest people may have a better chance of living longer if they are consuming these products less, says Jessica Lack, from Harvard University in Boston. "It's encouraging to see that these fermented products may have such a big positive health benefit, and it is important for men to eat these products less, but there is more to be done to make them healthier, especially in the food industry, where it remains relatively unclear whether or not they have any benefits for consumers," Lack says. A new report published on Friday in Nutrition suggests a link between fermented dairy foods and improved heart health. According to a new study published on Thursday in the Journal of the European Society of Clinical Oncology, eating a small daily dose of fermented foods like cheese, yoghurt and sour milk can help lower cholesterol levels. The study followed 2,000 men from 1984-1989 in Finland to examine the links between different dietary patterns, lifestyle and health issues, and how their dietary habits were associated with their risk of heart attack and stroke. They found that consumption of fermented dairy products was inversely associated with an increased risk of incident coronary heart disease
#
#
# Summary Generated:-The study suggests that doctors could save some money by replacing anticoagulants with aspirin, which can be more widely used than expensive prescription drugs to prevent clotting. The analysis of nearly 40,537 knee replacements in Michigan found few clots after surgery but a greater incidence of other blood clots. "The findings are an important step in reducing the cost of care for those who have knee surgeries and the need to take anticoagulant drugs after," says David Bernstein, Jr., a professor of health sciences at Michigan Institute of Technology and a leader of the new analysis. "We can do that with better information about the medications that are used to treat thrombosis before surgery and the drugs used during the hospital stay, when clots are most often detected." (Note: Aspirin has been widely used as a treatment for heart problems, and a number of studies now show it can be used for other ailments, including breast and kidney cancer) The study was conducted on patients in the Michigan Department of Orthopaedic Surgery, part of a larger U-M project to give patients the best possible recovery and outcomes after knee replacements. Aspirin was prescribed for patients' clot-prevention needs, but the majority of surgeons used aspirin instead of drugs to prevent blood clots like rivaroxaban. The findings could have major implications for how doctors treat hip and knee replacements.
#
#
# Summary Generated:-The surgery significantly decrease recurrence of a common brain condition and death rates in a recent clinical trial, say CedarsSinai neurosurgeons in a paper that's presented today at a major conference on the world's leadingStrokes.The technique is not approved for other neurological disorders, researchers say, and it is not widely available for the management of brain atherosclerosis, the cause of about half of strokes, especially in patients without prior health problems or who have chronic conditions that make it particularly difficult to restore brain function and blood supply. "These findings suggest that the EDAS surgery could play a critical role for treating ICAD, and may offer a more efficient approach for treating a disease that is prevalent, yet deadly, and often misunderstood," said study lead Dr. Nestor R. Gonzalez, a professor of Neurosurgery. "We hope that these findings will be used in other neurological disorders where surgery is impractical or impossible, and that they will spur other doctors to develop new treatments for brain atherosclerosis."The findings of the study are the latest to support the use of surgery to treat this common but lethal condition, which typically leads to stroke in one in every four people, or more than 2 million worldwide, according to estimates released by the World Stroke Congress on Wednesday in Montreal.
#
#
# Summary Generated:-The new test can tell which prostate cancer is dangerous, or manageable - saving patients their lives by treating them the way they really want to - rather than going in for unnecessary surgeries and treatments, say scientists in the UK and US, whose work was described in the British Journal of Clinical Oncology (BJCA) in an article published today (August 15th 2011). Physicists from York University have worked out how to identify prostate cancer through its chemical patterns, and have created a method for doing just that. They found that there are many patterns that can help detect cancer, and identified 17 that could help identify cancerous cells. The technique is now being studied to develop a new blood test that could identify those most likely to benefit, with more than 95% accuracy, from the prostate cancer drug dopatinib, currently the standard of care in the battle with cancer, and which is expected to be approved for use in 2014. The results could eventually help doctors choose between chemotherapy and radiotherapy, allowing doctors to treat patients with less radiation, which could cut treatment costs and provide a more efficient and more effective way of saving lives
#
#
# Summary Generated:-A'universal liquid biopsy blood test' developed by UK researchers to rule out cancer is now being developed, with a new system of analysing blood samples which it claims could help detect cancer more accurately. The test will be brought to market by an industrial partner in France, and the research team believe it will revolutionize the cancer diagnostics business, helping doctors to rule out the disease more accurately in cases where it is suspected in patients, or is too advanced to be spotted in traditional methods. Here are the full stories of the research into this innovative test and why it may be so valuable for treating patients with prostate and colorectal cancer who are not yet aware of the presence of cancer, as well as others with no clear idea about the disease who are currently treated with chemotherapy and radiotherapy and have no alternative diagnostic tools to help find out they are harboring the disease and thus have no chance of surviving the disease, could make cancer detection easier, faster, less expensive than current techniques, and provide doctors with new tools to diagnose and treat patients in a more accurate and efficient manner, without invasive and potentially unnecessary procedures and instrumentation, which can cause unnecessary discomfort and expense and is a big time distraction for the health service.
#
#
# Summary Generated:-New results suggest laser therapy may work well for many <n>women, especially those with GSM<n>who have been treated with a variety of different therapies over the course of months and are still suffering from their condition. The new results add to other recent studies in the field of genitourinary syndrome of menopause that found a link between multiple laser therapies and a decrease of pain and dryness for women who were treated with one or more of the treatments. More information on the latest studies, and tips for women on <n>how to deal with menopause, <n> is available at NAMS, the <n>  <n>portal to the menopause world <n> at www.manoeuvriersociety.org.<n> <n> <n>MENOPATHETIAN.com.<n> <n>By HOLLAND JOSHUA BERKSHIRE/ <n> <n>Dr JoAnn Pinkerton of The Women's Health Clinic at Cleveland Clinic's Hillcrest Hospital says more robust randomized, sham- controlled data are needed before women can confidently decide whether a laser is right for them.
#
#
# Summary Generated:-The new therapy can improve cancer survival for some patients, but more research is needed to see if it will enhance other cancer treatments, says a radiation oncologist at the Maryland Proton Treatment Center. It is now being offered in the same facility as proton radiotherapy, an advantage to patients because both therapies are given in an hour, rather than a day, so they are delivered to the body quickly, and in a comfortable room. Researchers are working on ways to better combine heat with radiation to better treat cancer cells, and the addition of the heat may increase the chance for survival for some people who have difficult-to-reach cancers, says the professor of radiation Oncology at UMSOM, who has studied thermal treatment and radiation therapy for over two decades, including research conducted at MPTC and other centers that offer thermal and proton treatments in the United States and Europe. The thermal therapy system was introduced last September and the proton therapy system was introduced last month, but the two treatments can be given in one setting to reduce the amount of time patients are required to receive them and to reduce the possibility of side effects that may result, including breathing difficulties or nausea and vomiting
#
#
# Summary Generated:-A high-quality diet could have an effect on how well people treat bipolar disorder, according to a clinical trial published today. The study has found that people who ate a high quality diet had more stable moods and were better able to deal with manic depression. The research is the most recent example of how dietary advice has been used to help people with illnesses such as heart problems, but it could also help treat some mental health conditions, such as depression. The study was supported by the Wellcome Sanger Institute and the UK's Drug and Poison Information Network, and was carried out by scientists at Deakin University in Australia, German University and the University of Texas Health Presbyterian in the US. It is presented in Barcelona on Tuesday 25th January at the 2016 European Conference on Nutrition and Obesity (ECNLP). Read the latest news about the conference and read articles and reviews of the best research and innovations from our experts in this exciting and fast growing area of Medicine & Dentistry. Find out how to find the best local deals for your next holiday, party or social event with The Telegraph Health Experts. Our Health Experts will help you navigate the ever-changing world of medicine to find the right food, drink, and lifestyle mix to help you get through the day - and over the weekend!
#
#
# Summary Generated:-The latest study shows that the care of midwife is safe and helps vulnerable pregnant women who might not be offered other health care providers, such as doctors, go into labour early or have low BIRTH WEIGHT babies. It is the biggest and largest study to date to investigate whether Midwifery can help low-income expectant mothers have a better birth, writes CBC News' Deborah Marshall in an editorial about the study. "We need more evidence to help ensure midwives and obstetricians are available to the women we serve, particularly in high income areas where there are more women than men and where they are less able to take care of themselves," says McGill University professor and senior fellow at the Canadian Institutes of Health Research Heather Sisson, author of a study on maternity services in Alberta published today that found midwives helped women have smaller, more manageable births and were less likely to use forceps and tongs during labour and birth. "If you want your baby to be smaller than normal, make it a midwife because midwives are well educated about what's happening to the fetus and how it can grow and thrive and be a healthy baby, which is what we think of as healthy pregnancies," she says in an interview. "We're not sure how many women will use midwifery care, but there are reasons why they should use midwives and we need more evidence about why that should happen, especially for low income women, she says.
#
#
# Summary Generated:-By Jennifer R. Miller, MD NEW YORK -- Treatment with a HER2- Targeted Cancer Vaccine Provide Clinical Benefit, Some of These Patients Will Never See Benefits Like This Until Now; One Patient's Cancer Has Turned Mysterious, One of Them Shows Hope for Other Cancers With Vaccine, One of Them Showed Signs of Hope For Another Patient But It Still Doesn't Stop Her Cancer From Growing, The Cancer Patient Is Still Fighting For Her Life But Not Even Her Cancer Could Be Defeated By The Vaccine, Study Shows, The vaccine, which contains a customized immune system to attack HER2, has had limited success, but some patients with the cancer show significant benefit, including some whose tumors had not responded to other treatments for the disease. Here is an analysis of the study and a discussion of its findings, as posted on Cancer Research Online (CRAP): New Data Suggest Vaccine Is 'Very Promiset' in treating Cancers That Are Overexpressing the Protein HER2: The results are from a phase I study showing that, among 11 patients with metastatic ovarian, breast and lung cancer, six had benefits, including two with stable disease, and four with a partial or complete response, indicating promising potential for vaccines against cancer. The vaccine, which is given through the layers of skin and consists of customized T-shirts--like clothing that is worn around the body--provides a direct and targeted approach for targeting tumors that are overactive or overexpressing the protein in the body's genes, and may provide new ways to fight these cancers, but may not give them a way to fight other types, too.
#
#
# Summary Generated:-A study shows a protein found in saliva and milk may protect the taste buds of patients undergoing cancer therapy, potentially improving the patients' lives and their appetites during chemo. The finding may have widespread medical applications, and could lead to future therapies to protect taste buds, not only during cancer treatment but throughout other treatments, including post-existing conditions, and even after recovery, when food is more vital to a person than the body has the ability to sustain itself, say the authors of the new paper published this week in Food & Functional Sciences. The finding may have wider medical applications, including for people living with chronic illnesses that cause poor appetite, depression, weight gain, and other problems like diabetes and rheumatoid arthritis. The research was conducted by a team of researchers including Virginia Tech University, the Wake Forest Baptist Medical Center, William Ray and Andrea Dietrich at the University's College of Agriculture, Engineering and Environmental Technology. The research was conducted by Susan Duncan, Associate Professor, University of Virginia's College of Agriculture, Life Sciences, who is also the leader of an international team of researchers studying whether lactoferrin, a highly bioactive Protein found in the milk of milk, can protect taste buds and smell from chemotherapy side effects.
#
#
# Summary Generated:-For the first times, research suggests that more patients live Longer If Treated with Prostate Removal Plus Radiation therapy, or " prostatectomy," a surgical removal and follow-up treatment, instead of the standard radiation therapy and hormoneblocking therapy. The new finding could change how people with advanced prostate cancer choose the option to fight the disease, and what they get in return, says the team of Philadelphia researchers who studied the patients for more than 10 years at Jefferson Health and at the University of Pennsylvania Medical School. "This study is a big deal for prostate cancer patients everywhere, and it has implications for medical care for all men with cancer. The results are particularly important for patients living in communities that suffer the worst from the disease, but may be overlooked by the general health care system," said one of the researchers. "For these men, who are often too weak or too fat, a prostatectomy, a less aggressive method of treating prostate cancer is often considered less effective. The new study suggests that this type of surgical removal and follow-up treatment might help improve overall survival in high-risk cancers, though there's some debate whether removing the prostate is the better approach for some patients. But we now have data linking it with survival. We may be able to save lives by making other treatments more efficient. We should look at these new studies carefully and consider the new data as we discuss our options."
#
#
# Summary Generated:-A motivational intervention has helped people who have lost weight to drop five times more pounds in the six months after using the service than those who didn't receive help at all. By Dr Sam Rigby, medical director, Health Check-ups. The results of a small study published today show that users of FIT, which combines talk and imagery as a motivational tool, were five times less likely to lose weight on the same amount of exercise during the intervention than people who took the MI approach, despite the group being given no diet/physical activities advice or education, nor were they asked to consume more calories or make lifestyle changes, as was usually the aim of most weight loss programs. Here are the details of what happened, when it did, and how it compares to other options for losing weight. You can read all about it in the Telegraph Health supplement, now available on newsagents and supermarkets across the UK. Find out how to lose weight and look better, including how you can be healthy and fit, plus find out how to stay healthy - follow the Telegraph Health Supplement on Tuesdays for the latest tips, advice and tips for keeping the weight off - plus watch a free special edition of The Telegraph featuring expert tips on how to stay healthy and fit
#
#
# Summary Generated:-The health benefits of playing golf are well-known, but a major consensus on how the game can promote healthy lifestyles for golfers and the broader public was reached this week. Here are some key conclusions: -Golf is a sociable and enjoyable activity with good mental and physical health; it also offers a range of social, emotional and physical rewards; players who take it up tend to stay active longer; it can be more expensive than other sports; it's not for everyone and should be embraced more; it can be played at all ages (but only for the right reasons; you don't have to be male, rich, or from a lower income family to play) -Golf has a wide range of participants and a diverse fan base -The Ryder Cup is taking place from August 26-31, 2014 in Straffan, Ohio (US); see below for live scores from the first round. -Follow the action at the course on TV via the Telegraph’s live blog - Find out how the US team won their last match against England at the Dunhill Links Championships on Thursday July 17 2014; check out all the live coverage here
#
#
# Summary Generated:-PHILADELPHIA, Pa., Aug. 20 -- Evivo, a clinical stage company, has introduced a rapid new diagnostic test for infants that can tell whether their baby has good gut bacteria that helps their development, which may help predict a healthy childhood and prevent chronic diseases. The Evivo Infant Gut Microbe Test was invented by a team of scientists and physicians from the University of Philadelphia who were inspired to create a simple and affordable new test that they believe can change infant microbiomes. With this test, pediatricians can detect and monitor the changing gut microbiome in as few as one day, which could provide parents with immediate and accurate testing for a number of issues, including eczema, IBS, colic, allergies and obesity, and prevent infants from becoming ill or developing chronic health conditions like asthma, allergies, and heart attack and stroke. "Evoli is committed to bringing new, innovative solutions to the millions of parents and doctors who are struggling with how to help babies grow up healthy, well and fit into their wheelchairs," says Daniel DeCarlo, Evivo's Chief executive officer. "This test is a game changer, and now we're ready to take on the rest of the market. We're looking forward to bringing this breakthrough product to the market later this year."
#
#
# Summary Generated:-Zika vaccine shows promise in killing glioblastoma stem cells, an incurable kind of brain cancer that is the reason why some people don't recover from it. In this latest study, researchers used the Zika virus to attack GSCs grown in lab dishes and mice model of the disease. This could help develop new treatments for this lethal cancer and even a cure for people living with glioblastoma, says lead researcher Pei-Yong Shi of UTEP's Galveston medical campus, who is studying the virus with his collaborators from Beijing's National Center of Biomedical Analysis. "Our research may help advance new treatments, which may someday lead to better diagnosis and better treatments for people who face this deadly cancer, says Shi. We're thrilled with how we got there and the way we are using this promising vaccine in humans to try and find new ways to prevent or even treat these terrible tumors," says Man. "We are hopeful that by developing this vaccine we will be able to develop better treatments and even acure for these terrible brain cancers, which can be extremely fatal." The Zika vaccine is safe and effective in mice, and is shown to work against other viral infections, but was not well known to be safe against cancer cells. The team has developed a vaccine that is liveattenuated to the Zika virus, and is much easier to inject than its older version. The next step is testing the vaccine on humans.
#
#
# Summary Generated:-New test can detect disease early and offer hope in the fight against it, which could be second deadliest type of cancer globally, reports research by Swedish scientists. The test is still only able to detect pancreatic cancer, while the possibility of surgical intervention exists, but the process may be much easier than traditional testing, which can be difficult in people with no underlying medical conditions or are not well suited to the patient's current lifestyle, the researchers say. Pancreatic cancer is still one of the most difficult illnesses to detect, and is still considered an 'endless' disease with few treatments, especially for patients with mutations of immune system genes that are active during the development of pancreatic cancer. A new test developed by Swedish researchers can identify the disease at earlier, more treatable stages, which could give hope to patients whose disease is still unable to be fully treated, but who may not be ready for conventional treatment or who have no existing treatment options. The test consists of dozens of antibody-rich fragments on which markers are selected based on how they match the immune systems response to tumours, including tumour-promoting antibodies, proteins that are produced by the bodys own immune system, and cancer-associated antigens
#
#
# Summary Generated:-Study suggests therapy may slow disease progression <n> By University of Texas Medical branch <n> Galveston<n> <n>GALVESTON, Texas - Researchers from The University&nbsp;of&nbsp; Texas Medical Branch at Galveston found that testosterone replacement therapy may slow disease&nbsp;prolongation of Chronic obstructive Pulmonary disease. &nbsp; The paper&nbsp;is currently available in Chronic Respiratory Disease.&nbsp;<n> COPD, is&nbsp; Predicted by theWorld Health Organization to be theThird-Leading Causes of Death Internationally by 2030, researchers found that testosterone replacement therapy may help slow down COPD progression, but may increase the chance that testosterone replacement therapy will worsen the conditions. <n> <n>Male testosterone levels were correlated with increased respiratory hospitalizations and the severity of lung fibrosis in COPD patients when testosterone was given instead of placebo. However, when men who used testosterone replacements also had a higher propensity for other health complications, testosterone therapy may help slow down the progression of COPD and may even be a better treatment than steroids for men with COPD.
#
#
# ...
#
#
# Summary Generated:-A new MRI technique may predict who will have persistent concussion symptoms, even those with no brain trauma, months or years after a concussion, says a study led by researchers at the UCSF Center for Magnetic Resonance in Science and Technology, or UCSF-SFX. The results were published January 13, 2017, online, in the journal " Neurotrauma," as an "expat," or proof-of-concept study that may provide clues to better care of patients following concussions, researchers said. The study involved 45 people with mild brain trauma -- a type of concussion that involves a hard landing on the head but does not require serious bleeding or bruising, or any other signs of brain injury. They were asked to ignore the symptoms for three weeks after the injury, and then they had MRIs to detect abnormal brain activity. The analysis showed patterns of brain activity six months after the scans that indicated a higher risk for post-concussive symptoms like headache, dizziness or confusion, even among people with no signs of brain injury, researchers said. In the long run, these data may help doctors and patients better understand their unique needs and expectations after concussion, the researchers said, which could lead to more targeted, earlier treatment of concussion patients, and potentially less long-term harm to their brains.
#
#
# Summary Generated:-A new international stage 3 trial found that regorafenib, a drug previously not approved for the treatment of HCC, increased survival in patients with the deadly liver disease who had been treated before and who were previously unable to afford other treatments. Regorafenib was the only drug shown to improve survival in people who had advanced stage of advanced HCC, a cancer that usually progresses within three months after initial treatment, even after the most commonly prescribed drugs have already failed to do much for them. The FDA granted priority review status to the drug earlier this month, saying it provides evidence of benefit in treating advanced stage of liver cancer for which no approved drug is available, especially since the disease typically strikes patients who are already at high risk because of factors such as smoking or being African American or Latino. The trial was conducted over 21 sites worldwide and involved 152 patients with advanced, Stage III or III chronic liver tumors. Dr. Llovet and Charissa Chang are both co- authors of the latest study in Lancet, published on January 16, 2017, which was based on a large international, multinational, clinical trial of the new drug.
#
#
# Summary Generated:-The results indicate chemotherapy before surgery may reduce recurrences and improve treatment outcomes in the African-American community, researchers say. The study's first authors added that this finding should have broad implications for patients, who often face a much different diagnosis than European- Americans, who also face increased likelihood of tumor recurrence during breast cancer treatment. "Further research to determine the exact role chemotherapy may have in preventing or lessening recurrence is needed to determine whether it actually helps patients survive longer after surgery, or even if it causes tumors to return when they're no longer localized to the body," said Dr. Robert A. Hall, a professor of medical science and radiation therapy at the Atlanta Cancer Institute. "Our findings show that chemo regimens prior to surgery may improve survival in African-Americans, but it is important to understand the differences between blacks and Europeans to develop more effective regimens for treatment of cancer in black patients," he said. "We are encouraged that this treatment is improving cancer survival in African American women, though there are many more patients to treat with this tool, including those with Stage IV tumors that have returned, which may be why our study shows it is beneficial in these patients."
#
#
# Summary Generated:-Newswise— Lap band surgery had significant benefits for severely obese teenagers but it was only used on children and teenagers who could afford the procedure and who were willing to make the decision on a permanent plan. A study conducted in the Netherlands showed lap band surgery to be more effective in teens who were morbidly overweight, but not necessarily obese, than those with a BMI under 40 kg. The procedure was also more effective when used on children who were already obese but not yet overweight, the study found. “It is still the most effective option available to overweight and obese teenagers if they wish to make the choice on a long term basis for managing their condition,” Dr Pea says. “The surgery is reversible, allowing teenagers to mature into a more informed decision whether they wish to undergo a longer-term operation or simply have the procedure as a short-term solution to morbid obesity. Lap band surgery has been shown to work effectively in adults with severe obesity and this work shows it can be done safely in children and adolescents who are severely obese. The findings suggest lap band surgery is an effective option for adolescents with severe obesity and that it may be a safe option for young patients who want to address the problem of obesity in adolescence
#
#
# Summary Generated:-Johns Hopkins researchers say scans show that those who are highest with calcium will benefit most, versus those whose levels are at the lowest. The findings may be important for patients with heart disease, those who have been treated with more aggressive treatments and for those whose blood pressure is in a "gray zone" where they do not need treatment, but who may be at risk for heart disease or who may already be taking anti-clotting medication, such as aspirin or stents. p>According to researchers from Johns Hopkins and colleagues, a scan that reveals the presence of calcium in coronary arteries may help physicians determine how aggressively to treat certain high-risk patients and help predict their future risks for heart disease, diabetes, heart attacks and strokes. These tests can also predict how many heart attacks or strokes would be avoided if someone with high blood pressure was treated appropriately. This new finding may be especially important for people who have high blood pressure, or who are taking medication for heart disease, because the risk for heart attack or heart disease increases as the number of people with blood pressure is high, and therefore more often those people will have a heart attack or a stroke, or are at particular risk of them. If doctors know which individuals should be aggressively treated, they can determine what therapy is most beneficial. This new data could improve treatment and management strategies, according to the National Health Service's 2015-2020-2020 Strategic Health Plan, a program that tracks the effects of various health systems' policies and initiatives across sectors.
#
#
# Summary Generated:-In women with multiple pregnancy losses, progesterone may help prevent miscarriages, new study suggests; researchers studied 116 women whose pregnancies had ended prematurely and found that some with abnormal uterine lining produced more endometrium to sustain an embryo, while other patients' linings were normal. The results, published in Fertility & Sterility, could be important in cases where multiple miscarriages have occurred or are occurring too often, and could have other consequences, including increased risk of other serious medical conditions. The study involved women in their early to late reproductive years, when a first pregnancy is less than a month old. About 25 percent of American women give birth within the first two to four weeks of pregnancy. A third of such women will suffer a loss of a pregnancy within four weeks, and about 40 percent of them will have another loss within a decade of conception, but most of those cases are resolved within the first 12 weeks. For these women, one solution may be a combination of treatment and lifestyle changes that may prevent a loss of a pregnancy. These strategies may include better nutrition, avoiding risky behaviors such as smoking and drinking and limiting alcohol intake in the weeks following pregnancy to reduce the chance of having a baby.
#
#
# Summary Generated:-University of Colorado Cancer Center researchers are reporting encouraging early results of a Phase Ib trial with tucatinib (formerly ONT-380), a promising drug that treats breast cancer patients who are already responding to current treatments. It may provide hope for many of the more than 80,000 women worldwide who face a triple negative diagnosis of HER2 breast cancer - the most deadly form of cancer - and may provide a new option for patients with early stage disease, or who have already tried other treatments and seen little benefit. The drug is also in a late stage FDA review for other breast cancer conditions, but the results from this latest trial could have a big impact on that development, which will determine whether tucatinib gets the fast-track status that is awarded to drugs that have shown great promise, especially when used against cancer in other forms of tumors, including prostate, lung, ovarian and skin cancers. A phase 1 clinical trial conducted in Israel found tucatinib was more effective than a standard of treatment in treating some patients with breast cancer whose tumors had responded to other treatments. Tucatinib may also have an important sideeffect: it is thought to cause some patients' immune cells to attack cancer cells, making it vulnerable to infection. "When we saw these data in Israel we thought that this could help a huge group of patients, especially in the early stages, and we've seen this in other diseases, too, so we're very excited now," Borges says.
#
#
# Summary Generated:-In the first study to show that tablets can reduce agitation and symptoms in older adults with dementia, researchers from the Virginia Tech Medical Center's Institute for Aging and Health Sciences have found that tablets can be safely used to control agitation, particularly among milder forms of dementia. The findings show that technology like tablets could be an effective way to enhance treatment for those who suffer from dementia, while allowing providers to tailor the treatment to the needs of a individual. The tablet devices, though, also provide a wide range of applications, from simple tasks to more complicated ones. The researchers also found that users were highly interested in the apps themselves: nearly 50 percent wanted to try every app available and nearly half of users said they were willing to use the apps as a substitute for a physical object. "We're excited about the potential for technology to be used to improve the health of older patients, especially with the growing population of elderly adults living in the United States, but the technology remains a relatively new idea, and our preliminary findings show that the technology may be useful for a wide range of different settings, including for the elderly who suffer from dementia and for older adults who have Alzheimer's or Parkinson's, as well as individuals with cognitive problems who struggle with everyday tasks like reading and crossword puzzles," said Vahia. The study is now being presented in the journal 'The Journal of geriatric psychiatry.'
#
#
# Summary Generated:-Scientists have discovered a way of stimulating stem cells to renew pulp in cavities, a method which could mean dentists can provide more natural and cheaper solutions to people who suffer from dental infections. The treatment was used on mice to show how it worked in humans, where it was shown to work better when treated with Collagen sponges, which are currently used by dentists for other purposes and which could be used for dentistry, as they are bio-degradable and deliver simple effects. The research is now being applied to human beings, with a focus on the treatment of tooth infections and gum disease, which affects about two million adults worldwide, but which is often neglected in dental practices because of its high cost, risks and poor outcomes. The findings should provide a more natural, affordable, and safe solution to people with cavities and other dental conditions, but will take time to prove out if the method is safe for humans, and whether it is viable for dental use or not, the team have been advised to consider using this new study in humans as an example, and to report back in a timely manner
#
#
# Summary Generated:-SecieraTM was designed by Ocular Technologies and Sun has the right, worldwide rights to its proprietary, novel nanomicellar formulation for the global commercialization of SecieraTM, which Sun believes is an innovative new class of treatment that could address the growing unmet needs of patients with dry eye and who are seeking new approaches for relief. Sun's management looks forward to discuss with US FDA next steps for the program and is proud to own the world-leading intellectual property of this promising new drug that could provide relief to a growing patient population in a very timely way, and is now in early development for market approval in China, Germany, Britain, the US, Europe and other markets around the world, where it has already shown great promise in some earlier stage clinical trials, and is already well tolerated and safe for patients, with good safety record and rapid onset of action. Statistically significant improvements were seen on key endpoints such as the primary end point of Schirmer's score and several other key Secondary endpoints such as...
#
#
# Summary Generated:-A modest, everyday diet of extra zinc has positive effects for your body, says study author Janet King, PhD. The study shows that an up dose of zinc is associated with lower oxidative stress, limiting damage to DNA and limiting inflammation. This results are important for addressing food insecurity, which can lead to malnutrition, but also because they may provide an affordable long-term solution to Zinc deficiency, which could be a sustainable food solution for developing countries, King said. The findings were published on January 3, 2017 as part of the journal's "Food: A Community Cookbook," which will be presented in New York City on Jan. 12. King is an associate professor of medicine and biochemistry and microbiology at the University of San Francisco and the lead author of the recent study, "Zinc: An Economic and Environmental Determinator of Nutrition" and "Bioavailability and Metabolism." He is also a professor of molecular, cellular and social pharmacology and microbiology at the University of Texas at Austin and a co-leader of the Department of Cell Science and Human Biology at Duke University. King is a co-author on the article, titled "Zinophilia: an Environmental Determinant of Oxidation-Related Deficiency"; she will present the research at the 2016 International Meeting on Biopharmaceutica and Cancer on Jan. 13, 2017, in New York City.

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading https://files.pythonhosted.org/packages/1f/56/a81022436c08b9405a5247b71635394d44fe7e1dbedc4b28c740e09c2840/rouge_score-0.0.4-py2.py3-none-any.whl
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from rouge_score) (3.2.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from rouge_score) (0.10.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from rouge_score) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rouge_score) (1.18.5)
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.0.4

# %%
from rouge_score import rouge_scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=False)


output = []
for i in range(len(summary_result)):
  t1 = summary_result[i]
  t2 = base_news_releases.loc[i,'Our Review Summary']
  text = base_news_releases.loc[i,'text']
  rating = base_news_releases.loc[i,'rating']
  id     = base_news_releases.loc[i,'id']
  
  scores_orignal_summary   = scorer.score(t2,text)
  fmeasure_orig_1          = scores_orignal_summary['rouge1'][2]
  fmeasure_orig_L          = scores_orignal_summary['rougeL'][2]
  
  scores_generated_summary = scorer.score(t1,text)
  fmeasure_gen_1           = scores_generated_summary['rouge1'][2]
  fmeasure_gen_L           = scores_generated_summary['rougeL'][2]
  output.append([id,text,t1,t2,fmeasure_gen_1,fmeasure_gen_L,fmeasure_orig_1,fmeasure_orig_L,rating])

# %%
df = pd.DataFrame(output,columns=['ID','Text','generated_summary','Original_summary',
                           'Rouge_score_Uni_gen','Rouge_score_fulllength_gen',
                           'Rouge_score_Uni_orig','Rouge_score_fulllength_orig','rating'
                           ])
df['ID'] =list(range(1,301))
df.to_csv('/content/output2.csv',index=False)
